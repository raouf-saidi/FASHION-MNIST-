# %% [markdown]
# # Introduction
# In this practical, we implement and train a feed-forward neural network (also known as an "MLP" for "multi-layer perceptron") on a dataset called "Fashion MNIST", consisting of small greyscale images of items of fashion.

# %% [markdown]
# # Learning Objectives
#
# * Understand how to use Keras Layers to build a neural network architecture
# * Understand how a model is trained and evaluated
# * Understand the concept of train/validation/test split and why it's useful

# %%
from __future__ import print_function
import tensorflow
import keras
from keras.datasets import fashion_mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout,Flatten
from tensorflow.keras.optimizers import RMSprop
import numpy as np 
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
import tensorflow_addons as tfa

# %%
pip install tensorflow_addons
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.18.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 5.2 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (21.3)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (2.7.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tensorflow_addons) (3.0.9)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.18.0

# %% [markdown]
# # Data
# In this practical, we use the Fashion MNIST dataset consisting of 70,000 greyscale images and their labels. The dataset is divided
#  into 60,000 training images and 10,000 test images. The idea is to train a **classifier** to identify the class value (what type of fashion item it is) given the image. We train and *tune* a model on the 60,000 training images and then evaluate how well it classifies the 10,000 test images that the model did not see during training. This task is an example of a **supervised learning** problem, where we are given both input and labels (targets) to learn from. This is in contrast to **unsupervised learning** where we only have inputs from which to learn patterns or **reinforcement learning** where an agent learns how to maximise a reward signal through interaction with its environment.

# %% [markdown]
# ![Texte alternatif…](https://res.cloudinary.com/practicaldev/image/fetch/s---fNWEeWA--/c_imagga_scale,f_auto,fl_progressive,h_420,q_auto,w_1000/https://raw.githubusercontent.com/zalandoresearch/fashion-mnist/master/doc/img/fashion-mnist-sprite.png)

# %% [markdown]
# # Train/Validation/Test Split
#
# When we build machine learning models, the goal is to build a model that will perform well on future data that we have not seen yet. We say that we want our models to be able to generalise well from whatever training data we can collect and do have available, to whatever data we will be applying them to in future. To do this, we split whatever data we have available into a training set, a validation set and a test set. The idea is that we train our model and use the performance on the validation set to make any adjustments to the model and its hyperparameters, but then we report the final accuracy on the test set. The test set (which we never train on), therefore acts as a proxy for our future data.

# %%
(train_and_validation_images, train_and_validation_labels), (test_images, test_labels) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
print(train_and_validation_labels.shape)
print(train_and_validation_images.shape)
# Out:
# (60000,)
# (60000, 28, 28)

# %%
# Construct a validation set from the last 10000 images and labels from 
# train_and_validation_images and train_and_validation_labels
validation_images = train_and_validation_images[-10000:, :, :]
validation_labels = train_and_validation_labels[-10000:]

# Construct a training set from the first 50000 images and labels.
train_images = train_and_validation_images[:50000, :, :]
train_labels = train_and_validation_labels[:50000]

# %%
text_labels = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
plt.figure()
random_index = np.random.randint(0, len(train_images))
plt.imshow(train_images[random_index], cmap='gray')
plt.colorbar()
numerical_label = train_labels[random_index]
text_description = text_labels[numerical_label]
plt.title('True Class: {} ("{}")'.format(numerical_label, text_description))

plt.gca().grid(False)

# %%
# Another view, showing 50 randomly selected images at a time
plt.figure(figsize=(20,20))
for i in range(50):
    plt.subplot(5,10,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid('off')
    
    img_index = np.random.randint(0, 50000)
    plt.imshow(train_images[img_index], cmap=plt.cm.gray)
    plt.xlabel(text_labels[train_labels[img_index]])

# %% [markdown]
# # Preprocess

# %%
train_images_flatten = train_images.reshape(train_images.shape[0], 784)
print(f'train_images_flatten : {train_images_flatten.shape}')
print(f'train_images : {train_images.shape}')
print(f'validation_images: {validation_images.shape}')
print(f' test_images {test_images.shape}')
# Out:
# train_images_flatten : (50000, 784)
# train_images : (50000, 28, 28)
# validation_images: (10000, 28, 28)
#  test_images (10000, 28, 28)

# %%
# Flatten
train_images_flatten = train_images.reshape(train_images.shape[0], 784)
validation_images_flatten = validation_images.reshape(validation_images.shape[0],784)
test_images_flatten = test_images.reshape(test_images.shape[0],784)

# %%
# Normalize
train_images = train_images/255.
validation_images = validation_images/255
test_images = test_images/255

# %%
# convert class vectors to binary class matrices
train_labels_categ = keras.utils.np_utils.to_categorical(train_labels, 10)
validation_labels_categ =keras.utils.np_utils.to_categorical(validation_labels, 10)
test_labels_categ = keras.utils.np_utils.to_categorical(test_labels, 10)

# %% [markdown]
# # Train

# %%
batch_size = 128
num_classes = 10
epochs = 40

# Create a sequential model here 
model = Sequential([
          Flatten(input_shape=(28,28)),
          Dense(128,activation='relu'),
          Dense(10,activation='softmax')

])

# End Code
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 128)               100480
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_labels_categ.shape
# Out:
# (50000, 10)

# %%
print(validation_images.shape,validation_labels_categ.shape)
# Out:
# (10000, 28, 28) (10000, 10)

# %%
model.compile(loss='categorical_crossentropy',metrics=["accuracy"
                                                           ,tfa.metrics.F1Score(
                                                           num_classes=10,
                                                           average='macro',
                                                           name='f1_score_macro'),
                                                           tfa.metrics.F1Score(
                                                           num_classes=10,
                                                           average='weighted',
                                                           name='f1_score_weighted')], optimizer='Adam')
history = model.fit(train_images, train_labels_categ,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(validation_images, validation_labels_categ))
# Out:
# Epoch 1/40
# 391/391 [==============================] - 4s 7ms/step - loss: 0.5746 - accuracy: 0.8041 - f1_score_macro: 0.8018 - f1_score_weighted: 0.8019 - val_loss: 0.4527 - val_accuracy: 0.8381 - val_f1_score_macro: 0.8333 - val_f1_score_weighted: 0.8332
# Epoch 2/40
# 391/391 [==============================] - 2s 6ms/step - loss: 0.4159 - accuracy: 0.8542 - f1_score_macro: 0.8534 - f1_score_weighted: 0.8535 - val_loss: 0.4133 - val_accuracy: 0.8557 - val_f1_score_macro: 0.8569 - val_f1_score_weighted: 0.8564
# Epoch 3/40
# 391/391 [==============================] - 2s 6ms/step - loss: 0.3753 - accuracy: 0.8679 - f1_score_macro: 0.8672 - f1_score_weighted: 0.8673 - val_loss: 0.3771 - val_accuracy: 0.8656 - val_f1_score_macro: 0.8649 - val_f1_score_weighted: 0.8644
# Epoch 4/40
# 391/391 [==============================] - 2s 6ms/step - loss: 0.3500 - accuracy: 0.8764 - f1_score_macro: 0.8757 - f1_score_weighted: 0.8758 - val_loss: 0.3662 - val_accuracy: 0.8691 - val_f1_score_macro: 0.8664 - val_f1_score_weighted: 0.8661
# Epoch 5/40
# 391/391 [==============================] - 2s 6ms/step - loss: 0.3307 - accuracy: 0.8817 - f1_score_macro: 0.8812 - f1_score_weighted: 0.8813 - val_loss: 0.3509 - val_accuracy: 0.8777 - val_f1_score_macro: 0.8761 - val_f1_score_weighted: 0.8758
# Epoch 6/40
# 391/391 [==============================] - 2s 5ms/step - loss: 0.3144 - accuracy: 0.8871 - f1_score_macro: 0.8867 - f1_score_weighted: 0.8868 - val_loss: 0.3571 - val_accuracy: 0.8699 - val_f1_score_macro: 0.8722 - val_f1_score_weighted: 0.8715
# Epoch 7/40
# 391/391 [==============================] - 2s 5ms/step - loss: 0.2987 - accuracy: 0.8918 - f1_score_macro: 0.8913 - f1_score_weighted: 0.8914 - val_loss: 0.3309 - val_accuracy: 0.8830 - val_f1_score_macro: 0.8839 - val_f1_score_weighted: 0.8835
# Epoch 8/40
# 391/391 [==============================] - 2s 5ms/step - loss: 0.2915 - accuracy: 0.8956 - f1_score_macro: 0.8952 - f1_score_weighted: 0.8953 - val_loss: 0.3422 - val_accuracy: 0.8813 - val_f1_score_macro: 0.8800 - val_f1_score_weighted: 0.8796
# Epoch 9/40
# 391/391 [==============================] - 2s 5ms/step - loss: 0.2766 - accuracy: 0.8999 - f1_score_macro: 0.8995 - f1_score_weighted: 0.8996 - val_loss: 0.3498 - val_accuracy: 0.8740 - val_f1_score_macro: 0.8725 - val_f1_score_weighted: 0.8721
# Epoch 10/40
# 391/391 [==============================] - 2s 5ms/step - loss: 0.2719 - accuracy: 0.9008 - f1_score_macro: 0.9005 - f1_score_weighted: 0.9006 - val_loss: 0.3215 - val_accuracy: 0.8849 - val_f1_score_macro: 0.8845 - val_f1_score_weighted: 0.8842
# Epoch 11/40
# 391/391 [==============================] - 2s 6ms/step - loss: 0.2591 - accuracy: 0.9067 - f1_score_macro: 0.9063 - f1_score_weighted: 0.9064 - val_loss: 0.3350 - val_accuracy: 0.8797 - val_f1_score_macro: 0.8792 - val_f1_score_weighted: 0.8787
# Epoch 12/40
# 391/391 [==============================] - 2s 5ms/step - loss: 0.2544 - accuracy: 0.9069 - f1_score_macro: 0.9065 - f1_score_weighted: 0.9066 - val_loss: 0.3294 - val_accuracy: 0.8819 - val_f1_score_macro: 0.8835 - val_f1_score_weighted: 0.8829
# Epoch 13/40
# 391/391 [==============================] - 2s 5ms/step - loss: 0.2453 - accuracy: 0.9109 - f1_score_macro: 0.9106 - f1_score_weighted: 0.9107 - val_loss: 0.3151 - val_accuracy: 0.8889 - val_f1_score_macro: 0.8896 - val_f1_score_weighted: 0.8891
# Epoch 14/40
# 391/391 [==============================] - 2s 5ms/step - loss: 0.2392 - accuracy: 0.9127 - f1_score_macro: 0.9123 - f1_score_weighted: 0.9124 - val_loss: 0.3145 - val_accuracy: 0.8866 - val_f1_score_macro: 0.8869 - val_f1_score_weighted: 0.8864
# Epoch 15/40
# 391/391 [==============================] - 2s 5ms/step - loss: 0.2353 - accuracy: 0.9141 - f1_score_macro: 0.9138 - f1_score_weighted: 0.9139 - val_loss: 0.3345 - val_accuracy: 0.8809 - val_f1_score_macro: 0.8807 - val_f1_score_weighted: 0.8800
# Epoch 16/40
# 391/391 [==============================] - 2s 5ms/step - loss: 0.2290 - accuracy: 0.9157 - f1_score_macro: 0.9154 - f1_score_weighted: 0.9155 - val_loss: 0.3313 - val_accuracy: 0.8843 - val_f1_score_macro: 0.8841 - val_f1_score_weighted: 0.8835
# Epoch 17/40
# 391/391 [==============================] - 2s 5ms/step - loss: 0.2236 - accuracy: 0.9181 - f1_score_macro: 0.9178 - f1_score_weighted: 0.9179 - val_loss: 0.3161 - val_accuracy: 0.8904 - val_f1_score_macro: 0.8895 - val_f1_score_weighted: 0.8891
# Epoch 18/40
# 391/391 [==============================] - 2s 5ms/step - loss: 0.2138 - accuracy: 0.9210 - f1_score_macro: 0.9207 - f1_score_weighted: 0.9208 - val_loss: 0.3228 - val_accuracy: 0.8890 - val_f1_score_macro: 0.8891 - val_f1_score_weighted: 0.8888
# Epoch 19/40
# 391/391 [==============================] - 2s 5ms/step - loss: 0.2103 - accuracy: 0.9230 - f1_score_macro: 0.9228 - f1_score_weighted: 0.9229 - val_loss: 0.3274 - val_accuracy: 0.8845 - val_f1_score_macro: 0.8843 - val_f1_score_weighted: 0.8838
# Epoch 20/40
# 391/391 [==============================] - 2s 6ms/step - loss: 0.2053 - accuracy: 0.9247 - f1_score_macro: 0.9244 - f1_score_weighted: 0.9245 - val_loss: 0.3304 - val_accuracy: 0.8850 - val_f1_score_macro: 0.8865 - val_f1_score_weighted: 0.8859
# Epoch 21/40
# 391/391 [==============================] - 2s 5ms/step - loss: 0.2007 - accuracy: 0.9270 - f1_score_macro: 0.9267 - f1_score_weighted: 0.9268 - val_loss: 0.3353 - val_accuracy: 0.8831 - val_f1_score_macro: 0.8835 - val_f1_score_weighted: 0.8828
# Epoch 22/40
# 391/391 [==============================] - 2s 5ms/step - loss: 0.1958 - accuracy: 0.9287 - f1_score_macro: 0.9284 - f1_score_weighted: 0.9285 - val_loss: 0.3177 - val_accuracy: 0.8915 - val_f1_score_macro: 0.8921 - val_f1_score_weighted: 0.8916
# Epoch 23/40
# 391/391 [==============================] - 2s 5ms/step - loss: 0.1893 - accuracy: 0.9307 - f1_score_macro: 0.9304 - f1_score_weighted: 0.9305 - val_loss: 0.3144 - val_accuracy: 0.8894 - val_f1_score_macro: 0.8901 - val_f1_score_weighted: 0.8896
# Epoch 24/40
# 391/391 [==============================] - 2s 5ms/step - loss: 0.1871 - accuracy: 0.9308 - f1_score_macro: 0.9306 - f1_score_weighted: 0.9307 - val_loss: 0.3180 - val_accuracy: 0.8900 - val_f1_score_macro: 0.8914 - val_f1_score_weighted: 0.8910
# Epoch 25/40
# 391/391 [==============================] - 2s 5ms/step - loss: 0.1836 - accuracy: 0.9327 - f1_score_macro: 0.9324 - f1_score_weighted: 0.9325 - val_loss: 0.3106 - val_accuracy: 0.8919 - val_f1_score_macro: 0.8920 - val_f1_score_weighted: 0.8916
# Epoch 26/40
# 391/391 [==============================] - 2s 5ms/step - loss: 0.1786 - accuracy: 0.9350 - f1_score_macro: 0.9347 - f1_score_weighted: 0.9348 - val_loss: 0.3355 - val_accuracy: 0.8842 - val_f1_score_macro: 0.8847 - val_f1_score_weighted: 0.8842
# Epoch 27/40
# 391/391 [==============================] - 3s 8ms/step - loss: 0.1754 - accuracy: 0.9360 - f1_score_macro: 0.9358 - f1_score_weighted: 0.9359 - val_loss: 0.3403 - val_accuracy: 0.8831 - val_f1_score_macro: 0.8855 - val_f1_score_weighted: 0.8850
# Epoch 28/40
# 391/391 [==============================] - 2s 5ms/step - loss: 0.1713 - accuracy: 0.9383 - f1_score_macro: 0.9381 - f1_score_weighted: 0.9382 - val_loss: 0.3288 - val_accuracy: 0.8893 - val_f1_score_macro: 0.8886 - val_f1_score_weighted: 0.8881
# Epoch 29/40
# 391/391 [==============================] - 2s 6ms/step - loss: 0.1647 - accuracy: 0.9392 - f1_score_macro: 0.9390 - f1_score_weighted: 0.9391 - val_loss: 0.3425 - val_accuracy: 0.8883 - val_f1_score_macro: 0.8876 - val_f1_score_weighted: 0.8872
# Epoch 30/40
# 391/391 [==============================] - 2s 5ms/step - loss: 0.1609 - accuracy: 0.9411 - f1_score_macro: 0.9409 - f1_score_weighted: 0.9410 - val_loss: 0.3262 - val_accuracy: 0.8903 - val_f1_score_macro: 0.8907 - val_f1_score_weighted: 0.8903
# Epoch 31/40
# 391/391 [==============================] - 2s 5ms/step - loss: 0.1589 - accuracy: 0.9426 - f1_score_macro: 0.9424 - f1_score_weighted: 0.9425 - val_loss: 0.3435 - val_accuracy: 0.8846 - val_f1_score_macro: 0.8842 - val_f1_score_weighted: 0.8837
# Epoch 32/40
# 391/391 [==============================] - 2s 6ms/step - loss: 0.1567 - accuracy: 0.9429 - f1_score_macro: 0.9427 - f1_score_weighted: 0.9428 - val_loss: 0.3333 - val_accuracy: 0.8907 - val_f1_score_macro: 0.8907 - val_f1_score_weighted: 0.8902
# Epoch 33/40
# 391/391 [==============================] - 2s 5ms/step - loss: 0.1494 - accuracy: 0.9450 - f1_score_macro: 0.9448 - f1_score_weighted: 0.9449 - val_loss: 0.3563 - val_accuracy: 0.8858 - val_f1_score_macro: 0.8870 - val_f1_score_weighted: 0.8865
# Epoch 34/40
# 391/391 [==============================] - 2s 6ms/step - loss: 0.1513 - accuracy: 0.9450 - f1_score_macro: 0.9448 - f1_score_weighted: 0.9449 - val_loss: 0.3597 - val_accuracy: 0.8844 - val_f1_score_macro: 0.8844 - val_f1_score_weighted: 0.8837
# Epoch 35/40
# 391/391 [==============================] - 2s 5ms/step - loss: 0.1458 - accuracy: 0.9471 - f1_score_macro: 0.9469 - f1_score_weighted: 0.9470 - val_loss: 0.3474 - val_accuracy: 0.8880 - val_f1_score_macro: 0.8882 - val_f1_score_weighted: 0.8878
# Epoch 36/40
# 391/391 [==============================] - 2s 5ms/step - loss: 0.1457 - accuracy: 0.9478 - f1_score_macro: 0.9476 - f1_score_weighted: 0.9476 - val_loss: 0.3442 - val_accuracy: 0.8919 - val_f1_score_macro: 0.8925 - val_f1_score_weighted: 0.8920
# Epoch 37/40
# 391/391 [==============================] - 2s 5ms/step - loss: 0.1380 - accuracy: 0.9498 - f1_score_macro: 0.9496 - f1_score_weighted: 0.9497 - val_loss: 0.3537 - val_accuracy: 0.8903 - val_f1_score_macro: 0.8902 - val_f1_score_weighted: 0.8898
# Epoch 38/40
# 391/391 [==============================] - 2s 5ms/step - loss: 0.1376 - accuracy: 0.9501 - f1_score_macro: 0.9499 - f1_score_weighted: 0.9500 - val_loss: 0.3526 - val_accuracy: 0.8891 - val_f1_score_macro: 0.8901 - val_f1_score_weighted: 0.8896
# Epoch 39/40
# 391/391 [==============================] - 2s 5ms/step - loss: 0.1330 - accuracy: 0.9519 - f1_score_macro: 0.9517 - f1_score_weighted: 0.9518 - val_loss: 0.3592 - val_accuracy: 0.8857 - val_f1_score_macro: 0.8859 - val_f1_score_weighted: 0.8855
# Epoch 40/40
# 391/391 [==============================] - 2s 5ms/step - loss: 0.1299 - accuracy: 0.9530 - f1_score_macro: 0.9528 - f1_score_weighted: 0.9529 - val_loss: 0.3770 - val_accuracy: 0.8875 - val_f1_score_macro: 0.8864 - val_f1_score_weighted: 0.8860

# %% [markdown]
# # Test

# %%
score = model.evaluate(test_images, test_labels_categ, verbose=0)
print('Test accuracy:', score[1])
# You should be able to get,at least, 88% accuracy
# Out:
# Test accuracy: 0.8822000026702881

# %%
test_logits = model.predict(test_images)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
test_logits
# Out:
# array([[1.03921455e-11, 1.42658665e-16, 2.29755687e-10, ...,
#         3.65287124e-04, 6.28988150e-09, 9.99461770e-01],
#        [6.78860408e-04, 9.86523987e-17, 9.99204814e-01, ...,
#         1.48969968e-19, 1.21676529e-14, 3.93178901e-19],
#        [8.96695131e-12, 9.99999940e-01, 1.88495849e-14, ...,
#         1.54588868e-25, 2.93464676e-16, 3.01035213e-25],
#        ...,
#        [6.22969765e-08, 6.72744907e-15, 8.33750402e-10, ...,
#         2.16175636e-06, 9.99995649e-01, 5.52222096e-18],
#        [1.94897515e-10, 9.99999940e-01, 1.36015310e-09, ...,
#         2.30049754e-16, 2.69763240e-11, 2.47499639e-14],
#        [4.68861228e-10, 2.49795952e-12, 2.77440160e-09, ...,
#         3.50517985e-05, 4.90385673e-07, 9.22319465e-09]], dtype=float32)

# %%
test_predictions = np.argmax(test_logits, axis=1)

# %%
t_train = np.argmax(train_labels_categ, axis=1)

# %%
test_predictions[:10]
# Out:
# array([9, 2, 1, 1, 6, 1, 4, 6, 5, 7])

# %%
train_labels.shape
# Out:
# (50000,)

# %%
plt.figure(figsize=(10,10))
for i in range(10):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid('off')
    
    img_index = np.random.randint(0, 1000)
    plt.imshow(test_images[img_index], cmap=plt.cm.gray)
    actual_label  = np.argmax(test_labels_categ[img_index])
    predicted_label = np.argmax(test_logits[img_index])
    
    plt.xlabel("Actual: {} ({})\n Predicted: {} ({})".format(
        actual_label, text_labels[actual_label], predicted_label, text_labels[predicted_label]
    ))
    
plt.tight_layout()
plt.show()
